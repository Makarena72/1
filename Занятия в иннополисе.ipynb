# %% [markdown]
# <a href="https://colab.research.google.com/github/Makarena72/1/blob/main/%D0%97%D0%B0%D0%BD%D1%8F%D1%82%D0%B8%D1%8F%20%D0%B2%20%D0%B8%D0%BD%D0%BD%D0%BE%D0%BF%D0%BE%D0%BB%D0%B8%D1%81%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("Motor_Vehicle_Collisions_-_Crashes.csv")
data
# Out:
#        CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0      09/11/2021       2:39       NaN       NaN        NaN        NaN
# 1      03/26/2022      11:45       NaN       NaN        NaN        NaN
# 2      06/29/2022       6:55       NaN       NaN        NaN        NaN
# 3      09/11/2021       9:35  BROOKLYN   11208.0  40.667202 -73.866500
# 4      12/14/2021       8:13  BROOKLYN   11233.0  40.683304 -73.917274
# ...           ...        ...       ...       ...        ...        ...
# 44387  02/20/2022       7:35    QUEENS   11412.0  40.698566 -73.769585
# 44388  02/20/2022       8:00  BROOKLYN   11226.0  40.641468 -73.959380
# 44389  01/08/2022       9:08  BROOKLYN   11228.0  40.617813 -74.006440
# 44390  01/08/2022      19:45  BROOKLYN   11223.0  40.607920 -73.970695
# 44391  01/08/2022      15:56       NaN       NaN  40.804417 -73.955376
#
#                       LOCATION           ON STREET NAME CROSS STREET NAME  \
# ...

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44392 entries, 0 to 44391
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH DATE                     44392 non-null  object
#  1   CRASH TIME                     44392 non-null  object
#  2   BOROUGH                        29083 non-null  object
#  3   ZIP CODE                       29077 non-null  float64
#  4   LATITUDE                       40934 non-null  float64
#  5   LONGITUDE                      40934 non-null  float64
#  6   LOCATION                       40934 non-null  object
#  7   ON STREET NAME                 32326 non-null  object
#  8   CROSS STREET NAME              20499 non-null  object
#  9   OFF STREET NAME                12066 non-null  object
#  10  NUMBER OF PERSONS INJURED      44392 non-null  int64
#  11  NUMBER OF PERSONS KILLED       44392 non-null  int64
# ...

# %% [markdown]
# В данной базе приводится сводка данных о произошедших ДТП с датами, временем, местонахождением, количеством пострадавших. С помощью команды .info() определено, что в исследуемой базе данных всего 44392 строки и 29 столбцов, 4 из которых имеют формат с плавающей точкой, 7 целочисленных и 17 имеют строковый формат. Также имеется большое количество пустых ячеек, особенно в столбцах CONTRIBUTING FACTOR VEHICLE 5 и VEHICLE TYPE CODE 5.  Максимальное количество пострадавших в аварии - 18 человек, из которых все являются водителями.

# %%
1+1
